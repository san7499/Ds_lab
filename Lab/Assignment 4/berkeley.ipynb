# %%
clocks = [10, 15, 20, 25]

# %%
print("Clock Times Before Synchronization:")
print(clocks)

# %%
avg = sum(clocks) / len(clocks)

print("\nAverage Time =", avg)

# %%
print("\nClock Times After Synchronization:")

# %%
for i in range(len(clocks)):
    clocks[i] = avg
    print("Processor", i+1, "=", clocks[i])
